# %% [markdown]
# # Bilgisayar Programlama – 6. Hafta Alıştırmalar
#
#
# Bu not defteri, 5 haftalık ders akışındaki işlenen konular temel alınarak hazırlanmıştır:
#
# - Veri Tipleri I: Sayılar ve Matematiksel İşlemler
# - Veri Tipleri II: Metinler (Strings)
# - Döngüler
# - Mantıksal Operatörler
# - Koşul İfadeleri
# - Fonksiyonlar

# %% [markdown]
# ## **1. Seviye**

# %% [markdown]
# ### Soru 1 (Kod Yazma)
#
# Kullanıcıdan iki sayı alın ve toplamlarını ekrana yazdıran bir Python programı yazın.

# %%
# Cevabınızı buraya yazınız

# %% [markdown]
# ### Soru 2 (Kod Yazma)
#
# Kullanıcıdan bir sayı alın ve sayının karesini hesaplayıp ekrana yazdıran bir Python programı yazın.

# %%
# Cevabınızı buraya yazınız

# %% [markdown]
# ### Soru 3 (Kod Yazma)
#
# Kullanıcıdan bir isim alın (Cevap olarak dersi veren öğretim üyesinin Adını ve Soyadını yazın.) ve ekrana `Merhaba <isim>` yazdıran bir program yazın.

# %%
# Cevabınızı buraya yazınız

# %% [markdown]
# ### Soru 4 (Kod Yazma)
#
# Kullanıcıdan bir sayı alın. Sayı pozitif, negatif veya sıfır ise bunu belirten bir program yazın.

# %%
# Cevabınızı buraya yazınız

# %% [markdown]
# ### Soru 5 (Kod Yazma)
#
# 1’den 10’a kadar olan sayıları ekrana yazdıran bir `for` döngüsü yazın.

# %%
# Cevabınızı buraya yazınız

# %% [markdown]
# ### Soru 6 (Kod Yazma)
#
# Bir string değişkeni (Adınız ve Soyadınız) tanımlayın ve uzunluğunu ekrana yazdırın.

# %%
# Cevabınızı buraya yazınız

# %% [markdown]
# ### Soru 7 (Çıktı Tahmini)
#
# Aşağıdaki kodun çıktısını tahmin edin:
# ```python
# x = 5
# y = 2
# print(x + y * 3)
# ```

# %%
# Cevabınızı buraya yazınız

# %% [markdown]
# ### Soru 8 (Çıktı Tahmini)
#
# Aşağıdaki kodun çıktısını tahmin edin:
# ```python
# text = "Python"
# print(text[-2])
# ```

# %%
# Cevabınızı buraya yazınız

# %% [markdown]
# ### Soru 9 (Kod Yazma)
#
# 1’den 20’ye kadar olan çift sayıları ekrana yazdıran bir program yazın.

# %%
# Cevabınızı buraya yazınız

# %% [markdown]
# ### Soru 10 (Çıktı Tahmini)
#
# Aşağıdaki kodun çıktısını tahmin edin:
# ```python
# for i in range(3):
#     print(i + i*5)
# ```

# %%
# Cevabınızı buraya yazınız

# %% [markdown]
# ## **2. Seviye**

# %% [markdown]
# ### Soru 11 (Kod Yazma)
#
# Kullanıcıdan üç sayı alın ve ortalamalarını hesaplayın.

# %%
# Cevabınızı buraya yazınız

# %% [markdown]
# ### Soru 12 (Kod Yazma)
#
# Bir sayının tek mi çift mi olduğunu kontrol eden program yazın.

# %%
# Cevabınızı buraya yazınız

# %% [markdown]
# ### Soru 13 (Kod Yazma)
#
# 1’den 100’e kadar olan sayıların toplamını hesaplayın.

# %%
# Cevabınızı buraya yazınız

# %% [markdown]
# ### Soru 14 (Kod Yazma)
#
# Kullanıcıdan alınan sayının faktöriyelini hesaplayın.

# %%
# Cevabınızı buraya yazınız

# %% [markdown]
# ### Soru 15 (Çıktı Tahmini)
#
# Aşağıdaki kodun çıktısını tahmin edin:
# ```python
# a = 10
# b = 3
# print(a // b + b**a)
# ```

# %%
# Cevabınızı buraya yazınız

# %% [markdown]
# ### Soru 16 (Kod Yazma)
#
# Kullanıcıdan bir kelime alın ve alınan kelimenin tersini yazdırın.

# %%
# Cevabınızı buraya yazınız

# %% [markdown]
# ### Soru 17 (Kod Yazma)
#
# Kullanıcıdan bir cümle alın ve kaç karakterden oluştuğunu hesaplayın.

# %%
# Cevabınızı buraya yazınız

# %% [markdown]
# ### Soru 18 (Kod Yazma)
#
# Bir kelimenin palindrom (baştan ve sonran okunuşu aynı olan kelimelerdir. Örn. ada, küçük, makam vb.) olup olmadığını kontrol edin.

# %%
# Cevabınızı buraya yazınız

# %% [markdown]
# ### Soru 19 (Çıktı Tahmini)
#
# Aşağıdaki kodun çıktısını tahmin edin:
# ```python
# text = "Congratulations"
# print(text[1:4])
# ```

# %%
# Cevabınızı buraya yazınız

# %% [markdown]
# ### Soru 20 (Kod Yazma)
#
# Kullanıcıdan alınan cümlede (En az 5 kelimeden oluşan bir cümle kurunuz.) kaç adet `a` harfi olduğunu bulun.

# %%
# Cevabınızı buraya yazınız

# %% [markdown]
# ### Soru 21 (Kod Yazma)
#
# 1’den 10’a kadar sayıların karelerini yazdırın.

# %%
# Cevabınızı buraya yazınız

# %% [markdown]
# ### Soru 22 (Kod Yazma)
#
# Kullanıcıdan alınan sayıya kadar olan sayıların toplamını hesaplayın.

# %%
# Cevabınızı buraya yazınız

# %% [markdown]
# ### Soru 23 (Kod Yazma)
#
# Aşağıdaki listedeki sayıların toplamını hesaplayan program yazın: `[3, 5, 7, 2]`

# %%
# Cevabınızı buraya yazınız

# %% [markdown]
# ### Soru 24 (Çıktı Tahmini)
#
# Aşağıdaki kodun çıktısını tahmin edin:
# ```python
# for i in range(1,5):
#     print(i*2)
# ```

# %%
# Cevabınızı buraya yazınız

# %% [markdown]
# ### Soru 25 (Kod Yazma)
#
# 1’den 50’ye kadar 3’e bölünebilen sayıları yazdırın.

# %%
# Cevabınızı buraya yazınız

# %% [markdown]
# ### Soru 26 (Kod Yazma)
#
# Kullanıcıdan bir not alın. 90 ve üzeri `AA`, 80 ve üzeri `BA`, 70 ve üzeri `BB`, diğer durumlarda `CC` yazdırın.

# %%
# Cevabınızı buraya yazınız

# %% [markdown]
# ### Soru 27 (Kod Yazma)
#
# Kullanıcıdan yaş alın. 0–12 arası `çocuk`, 13–19 arası `genç`, 20 ve üzeri `yetişkin` yazdırın.

# %%
# Cevabınızı buraya yazınız

# %% [markdown]
# ### Soru 28 (Çıktı Tahmini)
#
# Aşağıdaki kodun çıktısını tahmin edin:
# ```python
# x = 10
# if x > 5:
#     print("A")
# else:
#     print("B")
# ```

# %%
# Cevabınızı buraya yazınız

# %% [markdown]
# ### Soru 29 (Kod Yazma)
#
# Kullanıcıdan iki sayı alın ve büyük olanı yazdırın.

# %%
# Cevabınızı buraya yazınız

# %% [markdown]
# ### Soru 30 (Kod Yazma)
#
# Kullanıcıdan üç sayı alın ve en büyük olanı bulun.

# %%
# Cevabınızı buraya yazınız

# %% [markdown]
# ### Soru 31 (Kod Yazma)
#
# Bir kişinin sınava girebilmesi için `yaş >= 18` ve `mezuniyet == True` şartlarını kontrol eden program yazın.

# %%
# Cevabınızı buraya yazınız

# %% [markdown]
# ### Soru 32 (Çıktı Tahmini)
#
# Aşağıdaki kodun çıktısını tahmin edin:
# ```python
# x = True
# y = False
# print(x and y)
# ```

# %%
# Cevabınızı buraya yazınız

# %% [markdown]
# ### Soru 33 (Kod Yazma)
#
# Kullanıcıdan sıcaklık değeri alın. 0 altı için `donma`, 0–25 arası için `normal`, 25 üstü için `sıcak` yazdırın.

# %%
# Cevabınızı buraya yazınız

# %% [markdown]
# ### Soru 34 (Kod Yazma)
#
# Parametre (girdi) olarak aldığı sayıya kadar olan asal sayıları bulan (yazdıran) fonksiyon yazınız.

# %%
# Cevabınızı buraya yazınız

# %% [markdown]
# ### Soru 35 (Kod Yazma)
#
# 1'den 20'ye kadar olan sayıları yazdırırken 5'in katlarını atlayan bir fonksiyon yazınız.

# %%
# Cevabınızı buraya yazınız

# %% [markdown]
# ### Soru 36 (Kod Yazma)
#
# Sifre adında bir değişken tanımlayın (Doğum tarihiniz olsun). Kullanıcıdan 4 haneli bir şifre girmesini isteyin ve şifre doğru girilene kadar tekrar sormaya devam eden bir while döngüsü kurun.

# %%
# Cevabınızı buraya yazınız

# %% [markdown]
# ### Soru 37 (Çıktı Tahmini)
#
# Aşağıdaki kodun çıktısını tahmin edin:
# ```python
# print("AB" * 3)
# ```

# %%
# Cevabınızı buraya yazınız

# %% [markdown]
# ### Soru 38 (Kod Yazma)
#
# Bir silindirin hacmini hesaplayan (h ve r)  bir fonksiyon yazın.

# %%
# Cevabınızı buraya yazınız

# %% [markdown]
# ### Soru 39 (Çıktı Tahmini)
#
# Aşağıdaki kodun çıktısını tahmin edin:
# ```python
# def test(a=2):
#   return a*3;
#
# print(test())
# print(test(9))
# ```

# %%
# Cevabınızı buraya yazınız

# %% [markdown]
# ### Soru 40 (Kod Yazma)
#
# Bir listedeki en büyük sayıyı bulan fonksiyon yazın.

# %%
# Cevabınızı buraya yazınız

# %% [markdown]
# ## **3. Seviye**

# %% [markdown]
# ### Soru 41 (Kod Yazma)
#
# 1’den 100’e kadar sayılar için; 3’e bölünenlerde `3K`, 5’e bölünenlerde `5K`, hem 3 hem 5’e bölünenlerde `15K`, diğerlerinde `others` yazdıran program yazın.

# %%
# Cevabınızı buraya yazınız

# %% [markdown]
# ### Soru 42 (Kod Yazma)
#
# Kullanıcıdan alınan sayının asal olup olmadığını kontrol edin.

# %%
# Cevabınızı buraya yazınız

# %% [markdown]
# ### Soru 43 (Kod Yazma)
#
# Bir string içindeki büyük harf sayısını hesaplayın.

# %%
# Cevabınızı buraya yazınız

# %% [markdown]
# ### Soru 44 (Kod Yazma)
#
# Bir listedeki tekrarlayan elemanları bulan program yazın.

# %%
# Cevabınızı buraya yazınız

# %% [markdown]
# ### Soru 45 (Çıktı Tahmini)
#
# Aşağıdaki kodun çıktısını tahmin edin:
# ```python
# x = 0
# for i in range(3):
#     for j in range(2):
#         x += 1
# print(x)
# ```

# %%
# Cevabınızı buraya yazınız

# %% [markdown]
# ### Soru 46 (Kod Yazma)
#
# Kullanıcıdan alınan sayıya kadar Fibonacci dizisini yazdırın.

# %%
# Cevabınızı buraya yazınız

# %% [markdown]
# ### Soru 47 (Kod Yazma)
#
# Bir string (Dersliğinizin adını giriniz.) içinde en çok tekrar eden karakteri bulun.

# %%
# Cevabınızı buraya yazınız

# %% [markdown]
# ### Soru 48 (Çıktı Tahmini)
#
# Aşağıdaki kodun çıktısını tahmin edin:
# ```python
# def f(n):
#     if n == 1: return 1
#     return n + f(n-1)
#
# print(f(3))
# ```

# %%
# Cevabınızı buraya yazınız

# %% [markdown]
# ### Soru 49 (Kod Yazma)
#
# Bir sayının basamaklarının toplamını hesaplayan fonksiyon yazın.

# %%
# Cevabınızı buraya yazınız

# %% [markdown]
# ### Soru 50 (Çıktı Tahmini)
#
# Aşağıdaki kodun çıktısını tahmin edin:
# ```python
# def f(x):
#     if x > 0:
#         return x
#     else:
#         return -x
# print(f(-5))
# ```

# %%
# Cevabınızı buraya yazınız

# %% [markdown]
# ## **4. Seviye**

# %% [markdown]
# ### Soru 51 (Kod Yazma)
#
# Bir hastanın:
#
# * Sistolik kan basıncı
# * Diyastolik kan basıncı
#
# değerleri imput olarak girilecektir. Aşağıdaki işlemleri yapınız:
#
# - Nabız basıncını hesaplayın: (Nabız Basıncı = Sistolik – Diyastolik)
# - Ortalama arter basıncını hesaplayın: (OAB = (Sistolik + 2 × Diyastolik) / 3)
# -  Sonuçları float veri tipi olarak yazdırın.

# %%
# Cevabınızı buraya yazınız

# %% [markdown]
# ### Soru 52 (Kod Yazma)
#
# İf-Else yapısı kullanarak aşağıdaki sınıflamayı yapınız ve sonucu yazdırınız.
# *  Sistolik kan basıncı < 120 → Normal
# * 120 < Sistolik kan basıncı < 139 → Pre-hipertansiyon
# * Sistolik kan basıncı > 140  → Hipertansiyon

# %%
# Cevabınızı buraya yazınız
