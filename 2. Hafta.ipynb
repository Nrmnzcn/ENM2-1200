# %% [markdown]
# # HAFTA 2

# %% [markdown]
# ## **1. Veri Tipi (Data Type) Nedir?**
#
# Veri tipi, bir değişkenin hangi tür bilgiyi tuttuğunu ifade eder.
#
# Python’da temel veri tipleri:
#
# * integer (int) → tam sayılar
#
# * float → ondalıklı sayılar
#
# * complex → karmaşık sayılar
#
# * boolean → True / False
#
# * string (str) → metin (3.Hafta'da)

# %%
a = 10
b = 3.14
c = True
d = "Merhaba"

# %% [markdown]
# ### Yazdırma Komutu: "Print"

# %%
print(type(a))
print(type(b))
print(type(c))
print(type(d))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# <class 'str'>

# %% [markdown]
# ## **2. Değişkenler (Variables)**
#
# * Değişken = veri saklamak için kullanılan isimlendirilmiş alan.
#
# * Python’da tür belirtmeye gerek yoktur.

# %%
x = 5
y = 2.5
z = x + y

print(z)
# Out:
# 7.5

# %% [markdown]
# **Değişken isim kuralları:**
#
# * Harf veya _ ile başlar.
#
# * Boşluk içermez.
#
# * Sayı ile başlayamaz.
#
# * Türkçe karakter mümkün olduğunca kullanmayın (ı, ü, ö, ş, ç, ğ vb.)

# %%
2sayi = 5
# Out:
#   File "/tmp/ipython-input-827768757.py", line 1
#     2sayi = 5
#     ^
# SyntaxError: invalid decimal literal

# %%
sayi2 = 5

# %% [markdown]
# ## **3. Sayı Türleri**
# 🔹 Tam Sayı: int

# %%
a = 10
b = -3

# %%
print(a)
# Out:
# 10

# %% [markdown]
# 🔹 Ondalıklı Sayı: float

# %%
pi = 3.14159
sicaklik = -2.5

# %%
print(sicaklik)
# Out:
# -2.5

# %% [markdown]
# 🔹 Karmaşık Sayı: complex

# %%
z = 3 + 4j

# %%
print(z)
# Out:
# (3+4j)

# %% [markdown]
# ## **4. Temel Aritmetik Operatörler**

# %% [markdown]
# | Sembol | Anlamı |
# |-----------|-----------|
# | +  | Toplama |
# | -  | Çıkarma |
# | *  | Çarpma |
# | /  | Bölme |
# | %  | Mod (kalan) |
# | //  | Tam Bölme |
# | **  | Üs Alma |

# %% [markdown]
# ### Toplama

# %%
a = 10
b = 3

print(a + b)
# Out:
# 13

# %% [markdown]
# ### Çıkarma

# %%
x = 131
y = 37

print(x - y)
# Out:
# 94

# %% [markdown]
# ### Çarpma

# %%
s = 48
t = 17

print(48 * 17)
# Out:
# 816

# %% [markdown]
# ### Bölme

# %%
d = 96
e = 4

print(d/e)
# Out:
# 24.0

# %%
d = 111
e = 6

print(d/e)
# Out:
# 18.5

# %%
d = 0
e = 9

print(d/e)
# Out:
# 0.0

# %%
d = 12
e = 0

print(d/e)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipython-input-2141753142.py in <cell line: 0>()
#       2 e = 0
#       3
# ----> 4 print(d/e)
#
# ZeroDivisionError: division by zero

# %% [markdown]
# ### Mod

# %%
k = 129
l = 7

print(k % l)
# Out:
# 3

# %% [markdown]
# ### Tam Bölme

# %%
m = 613
n = 7

print(m // n)
# Out:
# 87

# %% [markdown]
# ### Üs

# %%
x = 2
y = 18

print(x ** y)
# Out:
# 262144

# %% [markdown]
# ## **5. İşlem Önceliği**
#
# Python matematikteki önceliği takip eder:
#
# 🔹 ()
#
# 🔹 **
#
# 🔹 * / // %
#
# 🔹 + -

# %%
sonuc1 = 10 + 2 * 3
sonuc2 = (10 + 2) * 3

print(sonuc1)
print(sonuc2)
# Out:
# 16
# 36

# %% [markdown]
# ## **6. Atama Operatörleri**

# %%
x = 10
x += 5   # x = x + 5
print(x)
# Out:
# 15

# %%
x -= 3   # x = x - 3
print(x)
# Out:
# 12

# %%
x *= 2   # x = x * 2
print(x)
# Out:
# 24

# %%
x /= 4   # x = x / 4
print(x)
# Out:
# 6.0

# %% [markdown]
# ## **7. Tip Dönüşümü (Type Casting)**

# %%
a = "5"
print(type(a))
# Out:
# <class 'str'>

# %%
b = int(a)
print(type(b))
# Out:
# <class 'int'>

# %%
print(b + 2)
# Out:
# 7

# %%
c = float(b)
print(type(c))
# Out:
# <class 'float'>

# %%
print(c + 0.5)
# Out:
# 5.5

# %%
int("merhaba")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-316757715.py in <cell line: 0>()
# ----> 1 int("merhaba")
#
# ValueError: invalid literal for int() with base 10: 'merhaba'

# %% [markdown]
# ## **8. Temel Matematik Fonksiyonları**

# %% [markdown]
# ### **Mutlak Değer:** abs()

# %%
abs(-5)
# Out:
# 5

# %% [markdown]
# ### **Yuvarlama:** round() veya round(x, y)

# %%
round(3.7)
# Out:
# 4

# %%
round(pi, 2)
# Out:
# 3.14

# %%
round(0.112 + 0.2267, 2)
# Out:
# 0.34

# %% [markdown]
# ### **Üs (Power, Kuvvet):** pow()

# %%
pow(2,3)
# Out:
# 8

# %%
Pow(9,2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1505224992.py in <cell line: 0>()
# ----> 1 Pow(9,2)
#
# NameError: name 'Pow' is not defined

# %% [markdown]
# ### **Minimum:** min()

# %%
min(3, 5, -9, 7)
# Out:
# -9

# %% [markdown]
# ### Maksimum

# %%
max(13, -25, 78, 45, 101)
# Out:
# 101

# %% [markdown]
# ## **9. math Kütüphanesi**
#
# Bir kütüphaneyi kullanabilmek için Python'a indirmek gerekir.
#
# `pip install paket_adı `
#
# Örnek: `pip install mealpy`
#
# şekinde yükleme yapılır. Ancak temel kütüphaneler python içerisimde mevcuttur. Bu yüzden yükleme yapmaya gerek kalmaz. Doğrudan çağırmamız yeterlidir. Çağırmak için aşağıdaki komut kullanılır.
#
# `import math`
#
# `import pandas as pd`
#
# `import numpy as np`

# %%
import math

# %% [markdown]
# ### **Karekök:** sqrt()

# %%
math.sqrt(144)
# Out:
# 12.0

# %% [markdown]
# ### **Pi sayısı:** pi

# %%
math.pi * 5
# Out:
# 15.707963267948966

# %% [markdown]
# ### **Trigonometrik kavramlar:** sin(), cos()

# %%
math.sin(math.pi/2)
# Out:
# 1.0

# %%
math.cos(45)
# Out:
# 0.5253219888177297

# %% [markdown]
# ### Logaritma: log()

# %%
math.log(10)
# Out:
# 2.302585092994046

# %%
math.log10(1000)
# Out:
# 3.0

# %% [markdown]
# ### **Faktöriyel:** factorial()

# %%
math.factorial(5)
# Out:
# 120

# %%
factorial_5 = 5 * 4 * 3 * 2 * 1
print(factorial_5)
# Out:
# 120

# %% [markdown]
# **"math"** kütüphanesine ait daha fazla içeriğe ulaşmak için [bağlantı linkine](https://docs.python.org/3/library/math.html) tıklayabilirsiniz.

# %% [markdown]
# ## **10. Bilimsel Gösterim**

# %%
x = 5e3
y = 2.5e-4

print(x)
print(y)
# Out:
# 5000.0
# 0.00025

# %% [markdown]
# ## **11. Kullanıcıdan Girdi Alma**

# %%
x = int(input("Bir sayı giriniz: "))
y = float(input("Ondalıklı sayı giriniz: "))

print(x + y)
# Out:
# Bir sayı giriniz: 72
# Ondalıklı sayı giriniz: -25.697
# 46.303

# %%
r = float(input("Yarıçap: "))
alan = math.pi * r**2
print("Alan:", alan)
# Out:
# Yarıçap: 8
# Alan: 201.06192982974676

# %%
a = float(input("1. not: "))
b = float(input("2. not: "))
c = float(input("3. not: "))

ortalama = (a + b + c) / 3
print("Ortalama:", ortalama)
# Out:
# 1. not: 25
# 2. not: 95
# 3. not: 88
# Ortalama: 69.33333333333333

# %% [markdown]
# ## **Alıştırmalar 1**
#
# İki değişken tanımlayın ve bu iki değişkenin
#
# * toplamını
#
# * farkını
#
# * çarpımını
#
# * bölümünü
#
# * ortalamasını
#
# yazdıran program yazınız.

# %% [markdown]
# ## **Alıştırmalar 2**
#
# Kullanıcıdan iki basamaklı bir sayı girmesini isteyiniz. Girilen sıcaklığı:
#
# * Celsius → Fahrenheit çeviriniz.
#
# **Not:** F = C × 1.8 + 32

# %% [markdown]
# ## **Alıştırmalar 3**
#
# Kullanıcıdan bir sayı alınız.
#
# Bu sayının:
#
# * Karesini
#
# * Küpünü
#
# hesaplayıp yazdırınız.

# %% [markdown]
# ## **Alıştırmalar 4**
#
# Kullanıcıdan iki sayı alınız.
# Büyük olan sayıyı bulunuz ve ekrana yazdırınız.

# %% [markdown]
# ## **Alıştırmalar 5**
#
# Kullanıcıdan dairenin yarıçapını alınız.
#
# Dairenin:
#
# * Çevresini
#
# * Alanını
#
# hesaplayınız.
#
# **Not:** (π = 3.14 alınabilir veya math.pi kullanılabilir.)

# %% [markdown]
# ## **Alıştırmalar 6**
#
# Kullanıcıdan kilometre cinsinden bir mesafe alınız.
#
# Bunu:
#
# * metreye
#
# * santimetreye
#
# çeviriniz.
